# %% [markdown]
# 데이터 준비하기

# %%
import pandas

# %%
# 미국 국립 알코올 남용 및 중독 연구소에서 발표한 2011년 실태조사 보고서
alcol2009 = pandas.read_csv('/content/niaaa-report2009.csv', index_col = "State")

# %%
alcol2009.head()
# Out:
#             Beer  Wine  Spirits
# State
# Alabama     1.20  0.22     0.58
# Alaska      1.31  0.54     1.16
# Arizona     1.19  0.38     0.74
# Arkansas    1.07  0.17     0.60
# California  1.05  0.55     0.73

# %%
alcol2009.tail()
# Out:
#                Beer  Wine  Spirits
# State
# Virginia       1.11  0.43     0.59
# Washington     1.09  0.51     0.74
# West Virginia  1.24  0.10     0.45
# Wisconsin      1.49  0.31     1.16
# Wyoming        1.45  0.22     1.10

# %%
alcol2009.size # 행 렬 곱한 값 ---> 안씀
# Out:
# 153

# %%
alcol2009.info()   # 데이터타입 확인 개꿀
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, Alabama to Wyoming
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Beer     51 non-null     float64
#  1   Wine     51 non-null     float64
#  2   Spirits  51 non-null     float64
# dtypes: float64(3)
# memory usage: 4.1+ KB

# %%
alcol2009.shape
# Out:
# (51, 3)

# %%
alcol2009['Wine'].head() # 밑 명령어와 같음
# Out:
# State
# Alabama       0.22
# Alaska        0.54
# Arizona       0.38
# Arkansas      0.17
# California    0.55
# Name: Wine, dtype: float64

# %%
alcol2009.Wine.head()
# Out:
# State
# Alabama       0.22
# Alaska        0.54
# Arizona       0.38
# Arkansas      0.17
# California    0.55
# Name: Wine, dtype: float64

# %%
# 새로운 열(column) 추가
alcol2009['Total'] = 0
alcol2009.head()
# Out:
#             Beer  Wine  Spirits  Total
# State
# Alabama     1.20  0.22     0.58      0
# Alaska      1.31  0.54     1.16      0
# Arizona     1.19  0.38     0.74      0
# Arkansas    1.07  0.17     0.60      0
# California  1.05  0.55     0.73      0

# %%
# 인덱스 변경하기 (어떤 열이라도 데이터 프레임의 인덱스가 될 수 있음)
alcol2009.reset_index().set_index('Beer').head()        #해당 컬럼을 공석으로 만든다.
# Out:
#            State  Wine  Spirits  Total
# Beer
# 1.20     Alabama  0.22     0.58      0
# 1.31      Alaska  0.54     1.16      0
# 1.19     Arizona  0.38     0.74      0
# 1.07    Arkansas  0.17     0.60      0
# 1.05  California  0.55     0.73      0

# %%
alcol2009.reset_index('State').head()
# Out:
#         State  Beer  Wine  Spirits  Total
# 0     Alabama  1.20  0.22     0.58      0
# 1      Alaska  1.31  0.54     1.16      0
# 2     Arizona  1.19  0.38     0.74      0
# 3    Arkansas  1.07  0.17     0.60      0
# 4  California  1.05  0.55     0.73      0

# %%
alcol2009.drop(['Total'], axis = 1)

# %%
alcol2009.loc['Nebraska']
# Out:
# Beer       1.46
# Wine       0.20
# Spirits    0.68
# Total      0.00
# Name: Nebraska, dtype: float64

# %%
# in 연산자 데이터 프레임의 특정 레이블을 가진 행이 있는지 확인 True or False
'Samoa' in alcol2009.index
# Out:
# False

# %%
'Nebraska' in alcol2009.index
# Out:
# True
