# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# 파이썬 버전확인

# %%
import sys
print('파이썬 버전은? : ' , sys.version)
# Out:
# 파이썬 버전은? :  3.7.10 (default, May  3 2021, 02:48:31)
# [GCC 7.5.0]
