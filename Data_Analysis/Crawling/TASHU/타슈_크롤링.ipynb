# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas
import time
import re

# %%
# 크롤링 정보를 저장할 데이터프레임 선언
data = pandas.DataFrame(columns=['스테이션명', '위치', '상태정보', '위도', '경도'])

# 크롤링 할 타슈 사이트 주소
url_tashu = 'http://www.tashu.or.kr/userStationAction.do?process=list'

# 페이지 이동 시 추가로 적어줘야 되는 url
url_add = '&page='

# 전체 페이지 수
total_page = 27

# 27 page에 대한 정보를 추출하는 for문
for index in range(1, total_page + 1):
  if index == 1:
    url = url_tashu
  else:
    url = url_tashu + url_add + str(index)  # 페이지 정보 추가

  # url에서 HTML 추출
  html = urlopen(url)

  # HTML을 파싱하여 데이터로 변환
  bsObject = BeautifulSoup(html, 'html.parser', from_encoding = 'utf-8')

  # history_table이라고 하는 class를 가진 table만 추출
  table = bsObject.find_all('table', {'class', 'history_table'})

  # table 내에서 tr 추출
  tr = table[0].find_all('tr')

  # 첫 tr은 contents 가 아니라, 데이터 정보를 의미하기 때문에 제외
  tr = tr[1:len(tr)]

  # 한 페이지의 정보를 크롤링
  for index_tr in range(0, len(tr)):
    td = tr[index_tr].find_all('td')

    # 장소
    station = td[0].text.split('.')[1]  # 1.무역전시관입구(택시승강장) 에서 1.은 빼려고

    # 위치
    location = td[1].text

    # 상태
    condition = td[2].text

    # 좌표추출
    geo = td[3].a.attrs['href'].split('(')[1] # '36.374389', '127.392375');" 추출

    # 위도, 경도 추출을 위한 데이터 클렌징
    geo = re.sub('[;)]','', geo)  # '36.374389', '127.392375');" -> '36.374389', '127.392375'
    detail_location = geo.replace("'", '')  # 작은 따옴표 삭제 -> 36.374389, 127.392375

    # 위도 Latitude
    lat = detail_location.split(',')[0]

    # 경도 Longitude
    lon = detail_location.split(',')[1]

    # data에 크롤링 결과 저장
    data = data.append({'스테이션명':station,
                        '위치':location,
                        '상태정보':condition,
                        '위도':lat,
                        '경도':lon},
                       ignore_index = True) # index 무시할거야

    print('Complete of ' + str(index_tr + 1) + 'information with' + str(index) + ' Page')
  # Crawling 막히는 것 방지
  time.sleep(1)

print('--------------------------------------------------------------------------------')
print(data)
# Out:
# Complete of 1information with1 Page
# Complete of 2information with1 Page
# Complete of 3information with1 Page
# Complete of 4information with1 Page
# Complete of 5information with1 Page
# Complete of 6information with1 Page
# Complete of 7information with1 Page
# Complete of 8information with1 Page
# Complete of 9information with1 Page
# Complete of 10information with1 Page
# Complete of 1information with2 Page
# Complete of 2information with2 Page
# Complete of 3information with2 Page
# Complete of 4information with2 Page
# Complete of 5information with2 Page
# Complete of 6information with2 Page
# Complete of 7information with2 Page
# Complete of 8information with2 Page
# Complete of 9information with2 Page
# Complete of 10information with2 Page
# Complete of 1information with3 Page
# Complete of 2information with3 Page
# Complete of 3information with3 Page
# Complete of 4information with3 Page
# Complete of 5information with3 Page
# Complete of 6information with3 Page
# Complete of 7information with3 Page
# Complete of 8information with3 Page
# Complete of 9information with3 Page
# Complete of 10information with3 Page
# Complete of 1information with4 Page
# Complete of 2information with4 Page
# Complete of 3information with4 Page
# Complete of 4information with4 Page
# Complete of 5information with4 Page
# Complete of 6information with4 Page
# Complete of 7information with4 Page
# Complete of 8information with4 Page
# Complete of 9information with4 Page
# Complete of 10information with4 Page
# Complete of 1information with5 Page
# Complete of 2information with5 Page
# Complete of 3information with5 Page
# Complete of 4information with5 Page
# Complete of 5information with5 Page
# Complete of 6information with5 Page
# Complete of 7information with5 Page
# Complete of 8information with5 Page
# Complete of 9information with5 Page
# Complete of 10information with5 Page
# Complete of 6information with18 Page
# Complete of 7information with18 Page
# Complete of 8information with18 Page
# Complete of 9information with18 Page
# Complete of 10information with18 Page
# Complete of 1information with19 Page
# Complete of 2information with19 Page
# Complete of 3information with19 Page
# Complete of 4information with19 Page
# Complete of 5information with19 Page
# Complete of 6information with19 Page
# Complete of 7information with19 Page
# Complete of 8information with19 Page
# Complete of 9information with19 Page
# Complete of 10information with19 Page
# Complete of 1information with20 Page
# Complete of 2information with20 Page
# Complete of 3information with20 Page
# Complete of 4information with20 Page
# Complete of 5information with20 Page
# Complete of 6information with20 Page
# Complete of 7information with20 Page
# Complete of 8information with20 Page
# Complete of 9information with20 Page
# Complete of 10information with20 Page
# Complete of 1information with21 Page
# Complete of 2information with21 Page
# Complete of 3information with21 Page
# Complete of 4information with21 Page
# Complete of 5information with21 Page
# Complete of 6information with21 Page
# Complete of 7information with21 Page
# Complete of 8information with21 Page
# Complete of 9information with21 Page
# Complete of 10information with21 Page
# Complete of 1information with22 Page
# Complete of 2information with22 Page
# Complete of 3information with22 Page
# Complete of 4information with22 Page
# Complete of 5information with22 Page
# Complete of 6information with22 Page
# Complete of 7information with22 Page
# Complete of 8information with22 Page
# Complete of 9information with22 Page
# Complete of 10information with22 Page
# Complete of 1information with23 Page
# Complete of 2information with23 Page
# Complete of 3information with23 Page
# Complete of 4information with23 Page
# Complete of 5information with23 Page
# Complete of 6information with23 Page
# Complete of 7information with23 Page
# Complete of 8information with23 Page
# Complete of 9information with23 Page
# Complete of 10information with23 Page
# Complete of 1information with24 Page
# Complete of 2information with24 Page
# Complete of 3information with24 Page
# Complete of 4information with24 Page
# Complete of 5information with24 Page
# Complete of 6information with24 Page
# Complete of 7information with24 Page
# Complete of 8information with24 Page
# Complete of 9information with24 Page
# Complete of 10information with24 Page
# Complete of 1information with25 Page
# Complete of 2information with25 Page
# Complete of 3information with25 Page
# Complete of 4information with25 Page
# Complete of 5information with25 Page
# Complete of 6information with25 Page
# Complete of 7information with25 Page
# Complete of 8information with25 Page
# Complete of 9information with25 Page
# Complete of 10information with25 Page
# Complete of 1information with26 Page
# Complete of 2information with26 Page
# Complete of 3information with26 Page
# Complete of 4information with26 Page
# Complete of 5information with26 Page
# Complete of 6information with26 Page
# Complete of 7information with26 Page
# Complete of 8information with26 Page
# Complete of 9information with26 Page
# Complete of 10information with26 Page
# Complete of 1information with27 Page
# Complete of 2information with27 Page
# --------------------------------------------------------------------------------
#                  스테이션명                 위치 상태정보         위도           경도
# 0       무역전시관입구(택시승강장)       유성구 도룡동 3-8    정상  36.374580   127.386131
# 1              대전컨벤션센터      유성구 도룡동 4-19    정상  36.374389   127.392375
# 2               한밭수목원1        서구 만년동 396    정상  36.368995   127.388451
# 3    초원아파트(104동 버스정류장)        서구 만년동 401    정상  36.367945   127.379302
# 4      둔산대공원 입구(버스정류장)   서구 둔산2동 1521-10    정상  36.364974   127.388856
# ..                 ...                ...  ...        ...          ...
# 257              천문대입구       유성구 신성동 458    정상  36.382848   127.355004
# 258              대덕대학교         유성구 장동 48    정상  36.390462   127.362420
# 259        오정농수산물 도매시장      대덕구 오정동 45-1    정상  36.357693   127.407763
# 260   도로교통공단(건너편 라도무스)      유성구 원신흥동 608    정상  36.332692   127.333128
# 261              반석 더샵       유성구 반석동 704    정상  36.390096   127.305095
#
# [262 rows x 5 columns]

# %% [markdown]
# 크롤링 저장하기

# %%
data.to_csv('TASHU.csv', encoding = 'utf-8-sig')
